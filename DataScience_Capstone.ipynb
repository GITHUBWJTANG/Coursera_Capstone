# %% [markdown]
# <H1>This notebook will be mainly used for the capstone project</H1>

# %%
#this notebook will be mainly used for the capstone project

import pandas as pd #import Pandas
import numpy as np #import Numpy

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %%
path = '/Data-Collisions.csv'
df_init = pd.read_csv(path)
#df_init.head()

# %%
df = df_init[['X','Y','STATUS','ADDRTYPE','LOCATION','SEVERITYCODE','SEVERITYDESC','COLLISIONTYPE','PERSONCOUNT','PEDCOUNT','PEDCYLCOUNT','VEHCOUNT','INCDTTM','JUNCTIONTYPE','SDOT_COLDESC','WEATHER','ROADCOND','LIGHTCOND','ST_COLDESC','HITPARKEDCAR']]
df.head()
# Out:
#             X          Y   STATUS      ADDRTYPE  \
# 0 -122.323148  47.703140  Matched  Intersection
# 1 -122.347294  47.647172  Matched         Block
# 2 -122.334540  47.607871  Matched         Block
# 3 -122.334803  47.604803  Matched         Block
# 4 -122.306426  47.545739  Matched  Intersection
#
#                                       LOCATION  SEVERITYCODE  \
# 0                   5TH AVE NE AND NE 103RD ST             2
# 1   AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N             1
# 2  4TH AVE BETWEEN SENECA ST AND UNIVERSITY ST             1
# 3     2ND AVE BETWEEN MARION ST AND MADISON ST             1
# 4              SWIFT AVE S AND SWIFT AV OFF RP             2
#
#                      SEVERITYDESC COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  \
# 0                Injury Collision        Angles            2         0
# 1  Property Damage Only Collision     Sideswipe            2         0
# 2  Property Damage Only Collision    Parked Car            4         0
# ...

# %%
df[['VEHCOUNT','PERSONCOUNT','SEVERITYCODE']].describe()
# Out:
#             VEHCOUNT    PERSONCOUNT   SEVERITYCODE
# count  194673.000000  194673.000000  194673.000000
# mean        1.920780       2.444427       1.298901
# std         0.631047       1.345929       0.457778
# min         0.000000       0.000000       1.000000
# 25%         2.000000       2.000000       1.000000
# 50%         2.000000       2.000000       1.000000
# 75%         2.000000       3.000000       2.000000
# max        12.000000      81.000000       2.000000
